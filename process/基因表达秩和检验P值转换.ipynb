# %% [markdown]
# # 基因表达秩和检验P值转换

# %%
import pandas as pd
from math import log

# %%
df_gene_p_value = pd.read_csv('../KEGG_data/GeneExp_Wilcoxon_test_Analysis_P_value_C2_KEGG_MEDICUS.csv', index_col=0)
df_gene_p_value.head()
# Out:
#            KEGG_MEDICUS_ENV_FACTOR_ARSENIC_TO_ELECTRON_TRANSFER_IN_COMPLEX_IV  \
# cell_line
# HL60                                                0.000061
# HEL                                                 0.000226
# MONOMAC6                                            0.000034
# LS513                                               0.000044
# A101D                                               0.000088
#
#            KEGG_MEDICUS_ENV_FACTOR_BENZO_A_PYRENRE_TO_CYP_MEDIATED_METABOLISM  \
# cell_line
# HL60                                                0.362909
# HEL                                                 0.732481
# MONOMAC6                                            0.967218
# LS513                                               0.344889
# A101D                                               0.865214
#
#            KEGG_MEDICUS_ENV_FACTOR_BPA_TO_RAS_ERK_SIGNALING_PATHWAY  \
# cell_line
# HL60                                                0.033813
# ...

# %%
# 将df_gene_p_value所有值转换为-log10(P)
df_gene_p_value = -df_gene_p_value.map(lambda x: log(x,10))
df_gene_p_value.head()
# Out:
#            KEGG_MEDICUS_ENV_FACTOR_ARSENIC_TO_ELECTRON_TRANSFER_IN_COMPLEX_IV  \
# cell_line
# HL60                                                9.703402
# HEL                                                 8.396370
# MONOMAC6                                           10.299400
# LS513                                              10.022229
# A101D                                               9.333347
#
#            KEGG_MEDICUS_ENV_FACTOR_BENZO_A_PYRENRE_TO_CYP_MEDIATED_METABOLISM  \
# cell_line
# HL60                                                1.013603
# HEL                                                 0.311319
# MONOMAC6                                            0.033331
# LS513                                               1.064534
# A101D                                               0.144778
#
#            KEGG_MEDICUS_ENV_FACTOR_BPA_TO_RAS_ERK_SIGNALING_PATHWAY  \
# cell_line
# HL60                                                3.386907
# ...

# %%
df_gene_p_value.to_csv('../KEGG_data/GeneExp_Wilcoxon_test_Analysis_Log10_P_value_C2_KEGG_MEDICUS.csv')
