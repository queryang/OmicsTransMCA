# %%
import pandas as pd
import numpy as np

# %%
# df_pathway_att = pd.read_csv('../../data/GEP_CellBlind_LUNG_pathway_attention.csv')
df_pathway_att = pd.read_csv('../../data/TransMCA_Pathway_Attention_lung_CellBlind_GEP_V2.csv')

df_pathway_att = df_pathway_att[df_pathway_att['cell_line'].isin(['EKVX','HCC827','LCLC103H','LU135','NCIH1299','NCIH146','NCIH1963','NCIH2170','NCIH2228','NCIH526','PC14','RERFLCSQ1'])]
# 重置索引
df_pathway_att = df_pathway_att.reset_index(drop=True)
print(df_pathway_att.shape)
df_pathway_att.head()
# Out:
# (2560, 622)
#              drug cell_line OncotreeCode  \
# 0  5-Fluorouracil    HCC827         LUAD
# 1   5-azacytidine    HCC827         LUAD
# 2           A-366    HCC827         LUAD
# 3          ABT737    HCC827         LUAD
# 4        AGI-5198    HCC827         LUAD
#
#    KEGG_MEDICUS_ENV_FACTOR_ARSENIC_TO_ELECTRON_TRANSFER_IN_COMPLEX_IV  \
# 0                                           0.001330
# 1                                           0.001296
# 2                                           0.001585
# 3                                           0.001464
# 4                                           0.001822
#
#    KEGG_MEDICUS_ENV_FACTOR_BENZO_A_PYRENRE_TO_CYP_MEDIATED_METABOLISM  \
# 0                                           0.002133
# 1                                           0.002275
# 2                                           0.002365
# 3                                           0.002022
# 4                                           0.002040
#
#    KEGG_MEDICUS_ENV_FACTOR_BPA_TO_RAS_ERK_SIGNALING_PATHWAY  \
# 0                                           0.001278
# 1                                           0.001074
# 2                                           0.001349
# 3                                           0.001198
# 4                                           0.001520
#
#    KEGG_MEDICUS_ENV_FACTOR_DCE_TO_DNA_ADDUCTS  \
# 0                                    0.001523
# 1                                    0.001551
# 2                                    0.001781
# 3                                    0.001639
# 4                                    0.001891
#
#    KEGG_MEDICUS_ENV_FACTOR_E2_TO_NUCLEAR_INITIATED_ESTROGEN_SIGNALING_PATHWAY  \
# 0                                           0.001472
# 1                                           0.001249
# 2                                           0.001311
# 3                                           0.001292
# 4                                           0.001306
#
#    KEGG_MEDICUS_ENV_FACTOR_E2_TO_RAS_ERK_SIGNALING_PATHWAY  \
# 0                                           0.001580
# 1                                           0.001387
# 2                                           0.001290
# 3                                           0.001385
# 4                                           0.001217
#
#    KEGG_MEDICUS_ENV_FACTOR_IRON_TO_ANTEROGRADE_AXONAL_TRANSPORT  ...  \
# 0                                           0.001249             ...
# 1                                           0.001061             ...
# 2                                           0.001360             ...
# 3                                           0.001202             ...
# 4                                           0.001568             ...
#
#    KEGG_MEDICUS_VARIANT_SCRAPIE_CONFORMATION_PRPSC_TO_26S_PROTEASOME_MEDIATED_PROTEIN_DEGRADATION  \
# 0                                           0.001668
# 1                                           0.001516
# 2                                           0.001273
# 3                                           0.001474
# 4                                           0.001155
#
#    KEGG_MEDICUS_VARIANT_SCRAPIE_CONFORMATION_PRPSC_TO_MGLUR5_CA2_APOPTOTIC_PATHWAY  \
# 0                                           0.001668
# 1                                           0.001729
# 2                                           0.001920
# 3                                           0.001746
# 4                                           0.001929
#
#    KEGG_MEDICUS_VARIANT_SCRAPIE_CONFORMATION_PRPSC_TO_PERK_ATF4_SIGNALING_PATHWAY  \
# 0                                           0.001440
# 1                                           0.001214
# 2                                           0.001316
# 3                                           0.001269
# 4                                           0.001335
#
#    KEGG_MEDICUS_VARIANT_SCRAPIE_CONFORMATION_PRPSC_TO_PRNP_PI3K_NOX2_SIGNALING_PATHWAY  \
# 0                                           0.001736
# 1                                           0.001631
# 2                                           0.001259
# 3                                           0.001552
# 4                                           0.001111
#
#    KEGG_MEDICUS_VARIANT_SCRAPIE_CONFORMATION_PRPSC_TO_TRANSPORT_OF_CALCIUM  \
# 0                                           0.001223
# 1                                           0.001060
# 2                                           0.001380
# 3                                           0.001221
# 4                                           0.001627
#
#    KEGG_MEDICUS_VARIANT_SCRAPIE_CONFORMATION_PRPSC_TO_VGCC_CA2_APOPTOTIC_PATHWAY  \
# 0                                           0.001608
# 1                                           0.001426
# 2                                           0.001285
# 3                                           0.001412
# 4                                           0.001197
#
#    KEGG_MEDICUS_VARIANT_TEL_AML1_FUSION_TO_TRANSCRIPTIONAL_REPRESSION  \
# 0                                           0.001578
# 1                                           0.001619
# 2                                           0.001834
# 3                                           0.001681
# 4                                           0.001906
#
#    KEGG_MEDICUS_VARIANT_TGFA_OVEREXPRESSION_TO_PI3K_SIGNALING_PATHWAY  \
# 0                                           0.001471
# 1                                           0.001248
# 2                                           0.001311
# 3                                           0.001292
# 4                                           0.001307
#
#    KEGG_MEDICUS_VARIANT_TMPRSS2_ERG_FUSION_TO_TRANSCRIPTIONAL_ACTIVATION  \
# 0                                           0.002139
# 1                                           0.002282
# 2                                           0.002371
# 3                                           0.002025
# 4                                           0.002042
#
#    KEGG_MEDICUS_VARIANT_TRK_FUSION_KINASE_TO_RAS_ERK_SIGNALING_PATHWAY
# 0                                           0.001453
# 1                                           0.001462
# 2                                           0.001712
# 3                                           0.001582
# 4                                           0.001870
#
# [5 rows x 622 columns]

# %%
# 将df_LUNG根据cell_line分组，再取每组drug列的交集
df_pathway_att_drug = df_pathway_att.groupby('cell_line')['drug'].apply(set).reset_index()
# 将df_LUNG_drug中的drug取交集
drugs = set.intersection(*df_pathway_att_drug['drug'])
print(len(drugs))
print(drugs)
# 取df_LUNG中drug中在drugs中的数据
df_pathway_att = df_pathway_att[df_pathway_att['drug'].isin(drugs)]
# 去掉drug = ABT737,AZD5582,Dactinomycin,Docetaxel,GSK1904529A,Navitoclax,Paclitaxel,Sabutoclax,Venetoclax
# df_pathway_att = df_pathway_att[~df_pathway_att['drug'].isin(['ABT737','AZD5582','Dactinomycin','Docetaxel','GSK1904529A','Navitoclax','Paclitaxel','Sabutoclax','Venetoclax'])]
# 重置索引
df_pathway_att = df_pathway_att.reset_index(drop=True)
print(df_pathway_att.shape)
# Out:
# 144
# {'MN-64', 'LGK974', 'Oxaliplatin', 'AZD8186', 'OSI-027', 'AGK2', 'Serdemetan', 'EPZ004777', 'AZD4547', 'OF-1', 'Ulixertinib', 'GW441756', 'MG-132', 'Paclitaxel', 'Motesanib', 'Ipatasertib', 'OTX015', 'Ibrutinib', 'Veliparib', 'Taselisib', 'Picolinici-acid', 'RVX-208', 'Tanespimycin', 'Camptothecin', 'Entinostat', 'GSK1904529A', 'SN-38', 'KRAS (G12C) Inhibitor-12', 'PFI3', 'Erlotinib', 'Nutlin-3a (-)', 'Temozolomide', 'MK-2206', 'Venetoclax', 'Rucaparib', 'Linsitinib', 'AZD7762', 'AGI-5198', 'AZD3759', 'Mirin', 'AZD5363', 'YK-4-279', 'Wnt-C59', 'MIRA-1', 'Staurosporine', 'Ruxolitinib', 'MK-1775', 'Vismodegib', 'Dactinomycin', 'Sabutoclax', 'AZ960', 'Irinotecan', 'Lenalidomide', 'SB590885', 'XAV939', 'GDC0810', 'Telomerase Inhibitor IX', 'Fulvestrant', 'Afatinib', 'Sorafenib', 'JNK Inhibitor VIII', 'AZD6738', 'RO-3306', 'GSK343', 'Crizotinib', 'LY2109761', 'Avagacestat', 'Palbociclib', 'GSK2578215A', 'LCL161', 'NVP-ADW742', 'Axitinib', 'I-BET-762', 'Vorinostat', 'SB216763', 'WIKI4', 'Afuresertib', 'Gefitinib', 'Entospletinib', 'Osimertinib', 'Dactolisib', 'Niraparib', 'PD0325901', 'GSK2606414', 'Nilotinib', 'Trametinib', 'Dinaciclib', 'Ribociclib', 'P22077', 'PD173074', 'Selumetinib', 'PRIMA-1MET', 'BMS-345541', 'SGC0946', 'PLX-4720', 'EHT-1864', 'VE-822', 'Pevonedistat', 'CCT007093', 'I-BRD9', 'CZC24832', '5-Fluorouracil', 'ZM447439', 'AZD5582', 'Gemcitabine', 'Tamoxifen', 'SCH772984', 'BMS-536924', 'IWP-2', 'WEHI-539', 'Bosutinib', 'Talazoparib', 'Doramapimod', 'Refametinib', 'Sepantronium bromide', 'Bortezomib', 'Alpelisib', 'PRT062607', 'Pictilisib', 'Luminespib', 'Uprosertib', 'Lestaurtinib', 'Lapatinib', 'Docetaxel', 'PCI-34051', 'EPZ5676', 'Cediranib', 'Epirubicin', 'JQ1', 'ABT737', 'AGI-6780', 'Dasatinib', 'Cyclophosphamide', 'PFI-1', 'NU7441', 'BMS-754807', 'KU-55933', 'WZ4003', 'ML323', 'Navitoclax', 'Savolitinib', 'Leflunomide', 'Buparlisib', 'Olaparib'}
# (1728, 622)

# %%
# 取df_pathway_att前三列数据
df_pathway_att_OncotreeCode = df_pathway_att.iloc[:, :3]
# 去掉第一列数据
# df_pathway_att_OncotreeCode = df_pathway_att_OncotreeCode.drop(['drug'], axis=1)
# 去重
df_pathway_att_OncotreeCode = df_pathway_att_OncotreeCode.drop_duplicates()
# 重置索引
df_pathway_att_OncotreeCode = df_pathway_att_OncotreeCode.reset_index(drop=True)
print(df_pathway_att_OncotreeCode.shape)
df_pathway_att_OncotreeCode.head()
# Out:
# (1728, 3)
#              drug cell_line OncotreeCode
# 0  5-Fluorouracil    HCC827         LUAD
# 1          ABT737    HCC827         LUAD
# 2        AGI-5198    HCC827         LUAD
# 3        AGI-6780    HCC827         LUAD
# 4            AGK2    HCC827         LUAD

# %%
# 对df_pathway_att.iloc[:, 3:]进行UMAP降维
import umap
umap_ = umap.UMAP(n_components=2)
df_pathway_att_umap = umap_.fit_transform(df_pathway_att.iloc[:, 3:])
df_pathway_att_umap.shape
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 # 对df_pathway_att.iloc[:, 3:]进行UMAP降维
# ----> 2 import umap
#       3 umap_ = umap.UMAP(n_components=2)
#       4 df_pathway_att_umap = umap_.fit_transform(df_pathway_att.iloc[:, 3:])
#
# ModuleNotFoundError: No module named 'umap'

# %%
# 将降维后的数据转换成dataframe
df_pathway_att_umap = pd.DataFrame(df_pathway_att_umap)
df_pathway_att_umap.columns = ['umap_1', 'umap_2']
df_pathway_att_umap.insert(0, 'cell_line', df_pathway_att['cell_line'])
df_pathway_att_umap.insert(1, 'OncotreeCode', df_pathway_att['OncotreeCode'])
df_pathway_att_umap.insert(2, 'drug', df_pathway_att['drug'])
# 将umap_1>0.002的数据标注出来，方便后面的数据分析
df_pathway_att_umap['umap_1>0.002'] = df_pathway_att_umap['umap_1'].apply(lambda x: 1 if x>0.002 else 0)
print(df_pathway_att_umap.shape)
df_pathway_att_umap.head()

# %%
# 设置颜色
# ['#984EA3','#FF7F00','#E41A1C','#4DAF4A','#377EB8']
# 设置颜色方案
palette = {'LUAD':'#377EB8', 
           'LCLC':'#FF7F00', 
           # 'NSCLC':'#4DAF4A',
           'LUSC':'#984EA3',
           'SCLC':'#E41A1C'}
# palette = {'LUAD':'#b9f2f0', 
#            'LCLC':'#d0bbff', 
#            'NSCLC':'#ff9f9b',
#            'LUSC':'#a6d854',
#            'SCLC':'#66c2a5'}

# %%
# 将df_pathway_att_pca的OncotreeCode列的值替换成颜色
df_pathway_att_umap['OncotreeCode'] = df_pathway_att_umap['OncotreeCode'].map(palette)

# %%
# 画出散点图，按照OncotreeCode进行着色
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('default')
# 设置全局字体
plt.rcParams['font.sans-serif'] = ['Bahnschrift']
plt.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(7, 6))
plt.scatter(x=df_pathway_att_umap['umap_1'], y=df_pathway_att_umap['umap_2'], c=df_pathway_att_umap['OncotreeCode'], s=2)
# Get the current axes, creating one if necessary.
# ax = plt.gca()
# Set the spines (the box) visibility
# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
# ax.spines['bottom'].set_visible(False)
# ax.spines['bottom'].set_linewidth(2)  # X轴线宽
# ax.spines['left'].set_linewidth(1)  # Y轴线宽
# ax.spines['bottom'].set_linewidth(1)
# 根据palette设置图例
for key, value in palette.items():
    plt.scatter([], [], c=value, label=key)
plt.legend(scatterpoints=1, frameon=True, labelspacing=0.5, loc='upper right', fontsize=12,edgecolor='black')


# title
plt.title('Pathway Attention Visualization of Lung Cancer Subtypes', fontsize=20)

# X轴：PCA1
plt.xlabel('umap_1', fontsize=15)
# Y轴：PCA2
plt.ylabel('umap_2', fontsize=15)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# plt.savefig('LUNG_pathway_attention_PCA.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
# 对df_pathway_att从第四列数据开始进行PCA降维，降维成2维数据
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(df_pathway_att.iloc[:, 3:])
df_pathway_att_pca = pca.transform(df_pathway_att.iloc[:, 3:])
df_pathway_att_pca.shape

# %%
# 将降维后的数据转换成dataframe
df_pathway_att_pca = pd.DataFrame(df_pathway_att_pca)
df_pathway_att_pca.columns = ['pca_1', 'pca_2']
df_pathway_att_pca.insert(0, 'cell_line', df_pathway_att['cell_line'])
df_pathway_att_pca.insert(1, 'OncotreeCode', df_pathway_att['OncotreeCode'])
df_pathway_att_pca.insert(2, 'drug', df_pathway_att['drug'])
# 将pca_1>0.002的数据标注出来，方便后面的数据分析
df_pathway_att_pca['pca_1>0.002'] = df_pathway_att_pca['pca_1'].apply(lambda x: 1 if x>0.002 else 0)
print(df_pathway_att_pca.shape)
df_pathway_att_pca.head()

# %%
# 将df_pathway_att_pca与df_pathway_att_OncotreeCode合并,按照index
# df_pathway_att_pca = pd.concat([df_pathway_att_pca, df_pathway_att_OncotreeCode], axis=1)
# print(df_pathway_att_pca.shape)
# df_pathway_att_pca.head()

# %%
# 设置颜色
# ['#984EA3','#FF7F00','#E41A1C','#4DAF4A','#377EB8']
# 设置颜色方案
palette = {'LUAD':'#377EB8', 
           'LCLC':'#FF7F00', 
           # 'NSCLC':'#4DAF4A',
           'LUSC':'#984EA3',
           'SCLC':'#E41A1C'}
# palette = {'LUAD':'#b9f2f0', 
#            'LCLC':'#d0bbff', 
#            'NSCLC':'#ff9f9b',
#            'LUSC':'#a6d854',
#            'SCLC':'#66c2a5'}

# %%
# 将df_pathway_att_pca的OncotreeCode列的值替换成颜色
df_pathway_att_pca['OncotreeCode'] = df_pathway_att_pca['OncotreeCode'].map(palette)

# %%
# 画出散点图，按照OncotreeCode进行着色
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('default')
# 设置全局字体
plt.rcParams['font.sans-serif'] = ['Bahnschrift']
plt.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(7, 6))
plt.scatter(x=df_pathway_att_pca['pca_1'], y=df_pathway_att_pca['pca_2'], c=df_pathway_att_pca['OncotreeCode'], s=9)
# Get the current axes, creating one if necessary.
# ax = plt.gca()
# Set the spines (the box) visibility
# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
# ax.spines['bottom'].set_visible(False)
# ax.spines['bottom'].set_linewidth(2)  # X轴线宽
# ax.spines['left'].set_linewidth(1)  # Y轴线宽
# ax.spines['bottom'].set_linewidth(1)
# 根据palette设置图例
for key, value in palette.items():
    plt.scatter([], [], c=value, label=key)
plt.legend(scatterpoints=1, frameon=True, labelspacing=0.5, loc='upper right', fontsize=12,edgecolor='black')


# title
plt.title('Pathway Attention Visualization of Lung Cancer Subtypes', fontsize=20)

# X轴：PCA1
plt.xlabel('PCA_1', fontsize=15)
# Y轴：PCA2
plt.ylabel('PCA_2', fontsize=15)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# plt.savefig('LUNG_pathway_attention_PCA.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
# 使用seaborn画图
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.scatterplot(x='pca_1', y='pca_2', hue='OncotreeCode', data=df_pathway_att_pca, s=10)
# title
plt.title('PCA on lung pathway attention', fontsize=20)

# X轴：PCA1
plt.xlabel('PCA_1', fontsize=15)
# Y轴：PCA2
plt.ylabel('PCA_2', fontsize=15)

# plt.savefig('LUNG_pathway_attention_PCA_seaborn.png', dpi=300, bbox_inches='tight')

plt.show()
