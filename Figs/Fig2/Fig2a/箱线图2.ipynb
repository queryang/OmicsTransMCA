# %% [markdown]
# # Fig2A: 各肺癌亚型细胞系 箱线图

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.colors as mcolors
import pandas as pd

# %%
df_data = pd.read_csv("../../data/LUNG_Filtered_barplot.csv")
df_data.head()
# Out:
#              drug cell_line  prediction OncotreeCode      IC50
# 0  5-Fluorouracil    HCC827    5.472933         LUAD  5.191741
# 1          ABT737    HCC827    2.832198         LUAD  4.389625
# 2        AGI-5198    HCC827    5.063128         LUAD  5.698307
# 3        AGI-6780    HCC827    4.925839         LUAD  5.258638
# 4            AGK2    HCC827    3.713538         LUAD  4.342128

# %%
import numpy as np

# 对于df_data，计算每一行IC50和prediction的RMSE
df_data['RMSE'] = np.sqrt((df_data['IC50'] - df_data['prediction'])**2)
df_data.head()
# Out:
#              drug cell_line  prediction OncotreeCode      IC50      RMSE
# 0  5-Fluorouracil    HCC827    5.472933         LUAD  5.191741  0.281192
# 1          ABT737    HCC827    2.832198         LUAD  4.389625  1.557427
# 2        AGI-5198    HCC827    5.063128         LUAD  5.698307  0.635179
# 3        AGI-6780    HCC827    4.925839         LUAD  5.258638  0.332799
# 4            AGK2    HCC827    3.713538         LUAD  4.342128  0.628590

# %%
palette = sns.color_palette("Set2", 5)
box_plot = sns.boxplot(data=df_data,y="RMSE",x="cell_line",hue="OncotreeCode",palette=palette, linewidth=1.6)
# 设置x轴标签倾斜45度
plt.xticks(rotation=45)
# box_plot.set_xticklabels(['LUSC', 'LUAD', 'LCLC', 'SCLC', 'NSCLC'], rotation=45)
# 将图例放在图的右边
box_plot.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
# 设置全局字体
plt.rcParams['font.sans-serif'] = ['Bahnschrift']
plt.rcParams['axes.unicode_minus'] = False
# 设置颜色方案
# palette = sns.color_palette("muted", 5)
# 'LUAD','LCLC','NSCLC','LUSC','SCLC'
palette = {'LUAD':'#b9f2f0',
           'LCLC':'#d0bbff',
           'NSCLC':'#ff9f9b',
           'LUSC':'#a6d854',
           'SCLC':'#66c2a5'}
# 创建箱线图
box_plot = sns.boxplot(data=df_data, y="Z-Score", x="cell_line", hue="Cell Lines", palette=palette, linewidth=1.6)

# 设置x轴标签倾斜45度
plt.xticks(rotation=45)

# 设置标题和轴标签
plt.title('Boxplot of Predicted Z-Score for Different Cell Lines')
plt.xlabel('Cell Lines')
plt.ylabel('Predicted LN IC50 (Z-Score)')

# 将图例放在图的右边，并设置图例的大小

box_plot.legend(loc='center left', bbox_to_anchor=(1, 0.5), title='Subtype')

# 添加网格线
# plt.grid(True)
# plt.tight_layout()
# plt.savefig('box_plot.png',dpi = 300)
# 显示图形
plt.show()
# plt.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 13
#       7 palette = {'LUAD':'#b9f2f0',
#       8            'LCLC':'#d0bbff',
#       9            'NSCLC':'#ff9f9b',
#      10            'LUSC':'#a6d854',
#      11            'SCLC':'#66c2a5'}
#      12 # 创建箱线图
# ---> 13 box_plot = sns.boxplot(data=df_data, y="Z-Score", x="cell_line", hue="Cell Lines", palette=palette, linewidth=1.6)
#      15 # 设置x轴标签倾斜45度
#      16 plt.xticks(rotation=45)
#
# File C:\anaconda3\envs\torchgpu1\Lib\site-packages\seaborn\categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
#    1590     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1591     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)
#    1594     legend="auto", ax=None, **kwargs
#    1595 ):
# -> 1597     p = _CategoricalPlotter(
#    1598         data=data,
#    1599         variables=dict(x=x, y=y, hue=hue),
#    1600         order=order,
#    1601         orient=orient,
#    1602         color=color,
#    1603         legend=legend,
#    1604     )
#    1606     if ax is None:
#    1607         ax = plt.gca()
#
# File C:\anaconda3\envs\torchgpu1\Lib\site-packages\seaborn\categorical.py:67, in _CategoricalPlotter.__init__(self, data, variables, order, orient, require_numeric, color, legend)
#      56 def __init__(
#      57     self,
#      58     data=None,
#    (...)
#      64     legend="auto",
#      65 ):
# ---> 67     super().__init__(data=data, variables=variables)
#      69     # This method takes care of some bookkeeping that is necessary because the
#      70     # original categorical plots (prior to the 2021 refactor) had some rules that
#      71     # don't fit exactly into VectorPlotter logic. It may be wise to have a second
#    (...)
#      76     # default VectorPlotter rules. If we do decide to make orient part of the
#      77     # _base variable assignment, we'll want to figure out how to express that.
#      78     if self.input_format == "wide" and orient in ["h", "y"]:
#
# File C:\anaconda3\envs\torchgpu1\Lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File C:\anaconda3\envs\torchgpu1\Lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File C:\anaconda3\envs\torchgpu1\Lib\site-packages\seaborn\_core\data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File C:\anaconda3\envs\torchgpu1\Lib\site-packages\seaborn\_core\data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `Z-Score` for `y`. An entry with this name does not appear in `data`.
